# %% [markdown]
# # 01 Data Ingestion
# This notebook will ingest and save the data to a local data folder. While our climate data is already in CSV format, we will need to use APIs to ingest and save the accident and speed limit data.

# %% [markdown]
# ### Imports & Setup

# %%
import pandas as pd
import requests
from sodapy import Socrata

client = Socrata("data.calgary.ca", None)
# Out:
# WARNING:root:Requests made without an app_token will be subject to strict throttling limits.

# %% [markdown]
# ### Weather Data
# This data was manually downloaded from climatedata.ca

# %%
weather = pd.read_csv("../data/climate-daily.csv")
weather.head()
# Out:
#             x          y      STATION_NAME  CLIMATE_IDENTIFIER  \
# 0 -114.000297  51.109447  CALGARY INT'L CS             3031094
# 1 -114.000297  51.109447  CALGARY INT'L CS             3031094
# 2 -114.000297  51.109447  CALGARY INT'L CS             3031094
# 3 -114.000297  51.109447  CALGARY INT'L CS             3031094
# 4 -114.000297  51.109447  CALGARY INT'L CS             3031094
#
#                  ID           LOCAL_DATE PROVINCE_CODE  LOCAL_YEAR  \
# 0  3031094.2016.3.1  2016-03-01 00:00:00            AB        2016
# 1  3031094.2016.3.2  2016-03-02 00:00:00            AB        2016
# 2  3031094.2016.3.3  2016-03-03 00:00:00            AB        2016
# 3  3031094.2016.3.4  2016-03-04 00:00:00            AB        2016
# 4  3031094.2016.3.5  2016-03-05 00:00:00            AB        2016
#
#    LOCAL_MONTH  LOCAL_DAY  ...  SPEED_MAX_GUST SPEED_MAX_GUST_FLAG  \
# 0            3          1  ...            35.0                 NaN
# 1            3          2  ...            33.0                 NaN
# 2            3          3  ...            57.0                 NaN
# 3            3          4  ...             0.0                 NaN
# 4            3          5  ...            57.0                 NaN
#
#    COOLING_DEGREE_DAYS COOLING_DEGREE_DAYS_FLAG  HEATING_DEGREE_DAYS  \
# 0                  0.0                      NaN                 18.6
# 1                  0.0                      NaN                 19.3
# 2                  0.0                      NaN                 14.0
# 3                  0.0                      NaN                 14.2
# 4                  0.0                      NaN                 11.4
#
#   HEATING_DEGREE_DAYS_FLAG  MIN_REL_HUMIDITY MIN_REL_HUMIDITY_FLAG  \
# 0                      NaN               NaN                   NaN
# 1                      NaN               NaN                   NaN
# 2                      NaN               NaN                   NaN
# 3                      NaN               NaN                   NaN
# 4                      NaN               NaN                   NaN
#
#    MAX_REL_HUMIDITY MAX_REL_HUMIDITY_FLAG
# 0               NaN                   NaN
# 1               NaN                   NaN
# 2               NaN                   NaN
# 3               NaN                   NaN
# 4               NaN                   NaN
#
# [5 rows x 36 columns]

# %% [markdown]
# ### Speed Limit Data

# %%
# Get data from Socrata api endpoint
speeds_raw = client.get("2bwu-t32v", limit=3700)

# Convert to pandas DataFrame
speeds_df = pd.DataFrame.from_records(speeds_raw)

# %%
# Display preview of data
speeds_df.head()
# Out:
#   bound             distance speed            street_name  \
# 0   N/S           4.18265009    60  TWELVE MILE COULEE RD
# 1     E              1.85402    60         JOHN LAURIE BV
# 2     W   1.5454200500000002    60         JOHN LAURIE BV
# 3     W  0.47580501000000003    60           CROWCHILD TR
# 4   N/S           0.82496297    60                  11 ST
#
#       modified_attribute_dt  \
# 0  2012-08-20T14:38:13.000Z
# 1                       NaN
# 2                       NaN
# 3                       NaN
# 4                       NaN
#
#                                            multiline created_dt
# 0  {'type': 'MultiLineString', 'coordinates': [[[...        NaN
# 1  {'type': 'MultiLineString', 'coordinates': [[[...        NaN
# 2  {'type': 'MultiLineString', 'coordinates': [[[...        NaN
# 3  {'type': 'MultiLineString', 'coordinates': [[[...        NaN
# 4  {'type': 'MultiLineString', 'coordinates': [[[...        NaN

# %%
# Save data to our data folder
speeds_df.to_csv('../data/speed_limits.csv')

# %% [markdown]
# ### Traffic Accident Data

# %%
traffic_raw = client.get("35ra-9556", limit=50000)

# Convert to pandas DataFrame
traffic_df = pd.DataFrame.from_records(traffic_raw)

# %%
# View first five rows of our data
traffic_df.head()
# Out:
#                                        incident_info  \
# 0      Westbound Stoney Trail after Sarcee Trail NW
# 1   Southbound Deerfoot Trail approaching country...
# 2   Eastbound Glenmore Trail after Blackfoot Trai...
# 3      Eastbound Mcknight Blvd at Deerfoot Trail NE
# 4   Northbound Harvest Hills Boulevard ramp to Ea...
#
#                                        description                 start_dt  \
# 0     Two vehicle incident. Blocking the left lane  2026-01-07T14:53:09.000
# 1     Two vehicle incident. Blocking the left lane  2026-01-07T14:46:49.000
# 2   Two vehicle incident. Blocking the centre lane  2026-01-07T14:33:52.000
# 3     Two vehicle incident. Blocking the left lane  2026-01-07T13:59:21.000
# 4  Traffic incident.   Blocking the right shoulder  2026-01-07T04:56:28.000
#
#                modified_dt quadrant            longitude            latitude  \
# 0  2026-01-07T07:56:40.000       NW   -114.1703639573997   51.15181499196338
# 1  2026-01-07T07:56:40.000       NE  -114.01057928402363   51.15948611863427
# 2  2026-01-07T07:56:40.000       SE  -114.04798785240116   50.99433858658668
# 3  2026-01-07T07:56:40.000       NE  -114.03982359234142  51.096056352608926
# 4  2026-01-06T22:00:34.000       NE  -114.06700224840871   51.17262999470791
#
#   count                                                 id  \
# 0     1  2026-01-07T14:53:0951.15181499196338-114.17036...
# 1     1  2026-01-07T14:46:4951.15948611863427-114.01057...
# 2     1  2026-01-07T14:33:5250.99433858658668-114.04798...
# 3     1  2026-01-07T13:59:2151.096056352608926-114.0398...
# 4     1  2026-01-07T04:56:2851.17262999470791-114.06700...
#
#                                                point  \
# 0  {'type': 'Point', 'coordinates': [-114.1703639...
# 1  {'type': 'Point', 'coordinates': [-114.0105792...
# 2  {'type': 'Point', 'coordinates': [-114.0479878...
# 3  {'type': 'Point', 'coordinates': [-114.0398235...
# 4  {'type': 'Point', 'coordinates': [-114.0670022...
#
#   :@computed_region_kxmf_bzkv :@computed_region_4a3i_ccfj  \
# 0                         202                           2
# 1                         163                           4
# 2                           1                           3
# 3                          81                           4
# 4                         251                           4
#
#   :@computed_region_4b54_tmc4
# 0                           3
# 1                          11
# 2                          10
# 3                           9
# 4                          11

# %%
# Save our data as a CSV
traffic_df.to_csv("../data/traffic_accidents.csv")
